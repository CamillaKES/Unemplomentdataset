# %% [markdown]
# # Unemployment Data Analysis

# %% [markdown]
# # 1. Introduction
#
# One of the most problem the global is facing today is Unemployment, which is a sign of the state of the economy.it has an immediate effect on people's lives, income distribution, and general social stability in addition to signaling the state of an economy chanllenge faced by the countries acroos the globe. Understanding unemployment trends at a global level provides valuable insights into how different years are affected by economic cycles ,policy decisions ,technologica changes , and unexpected global events for example in the year 2021 we faced corona virus , the country faced a financial crises.
# on my codes i showed more visualisation on the year

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv(r"Desktop/camilla/unemployment analysis.csv")

# %%
# the frist 5 rows of the dataset
df.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %%
# the last rows of the dataset
df.tail()
# Out:
#      Country Name Country Code   1991   1992   1993   1994   1995   1996  \
# 230         Samoa          WSM   2.10   2.38   2.63   3.04   3.19   3.47
# 231   Yemen, Rep.          YEM   8.32   8.31   8.35   8.34   8.96   9.59
# 232  South Africa          ZAF  29.95  29.98  29.92  29.89  29.89  29.87
# 233        Zambia          ZMB  18.90  19.37  19.70  18.43  16.81  15.30
# 234      Zimbabwe          ZWE   4.94   4.99   4.97   4.96   5.63   6.25
#
#       1997   1998  ...   2012   2013   2014   2015   2016   2017   2018  \
# 230   3.90   4.18  ...   8.75   8.67   8.72   8.50   8.31   8.58   8.69
# 231  10.20  10.81  ...  13.17  13.27  13.47  13.77  13.43  13.30  13.15
# 232  29.91  29.95  ...  24.73  24.56  24.89  25.15  26.54  27.04  26.91
# 233  13.64  12.00  ...   7.85   8.61   9.36  10.13  10.87  11.63  12.01
# 234   6.93   6.46  ...   5.15   4.98   4.77   4.78   4.79   4.78   4.80
#
#       2019   2020   2021
# 230   8.41   9.15   9.84
# 231  13.06  13.39  13.57
# ...

# %%
# displaying the attributes of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  235 non-null    object
#  1   Country Code  235 non-null    object
#  2   1991          235 non-null    float64
#  3   1992          235 non-null    float64
#  4   1993          235 non-null    float64
#  5   1994          235 non-null    float64
#  6   1995          235 non-null    float64
#  7   1996          235 non-null    float64
#  8   1997          235 non-null    float64
#  9   1998          235 non-null    float64
#  10  1999          235 non-null    float64
#  11  2000          235 non-null    float64
#  12  2001          235 non-null    float64
#  13  2002          235 non-null    float64
#  14  2003          235 non-null    float64
#  15  2004          235 non-null    float64
#  16  2005          235 non-null    float64
# ...

# %%
# Displaying the extensively of the dataset
df.describe
# Out:
# <bound method NDFrame.describe of                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
# ...

# %%
# Display the null value
df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 1991            0
# 1992            0
# 1993            0
# 1994            0
# 1995            0
# 1996            0
# 1997            0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
# Showing the histrogram for 2021
sns.histplot(df["2021"],kde = True)
plt.show()

# %%
#Compare by year 1991 and 1993
sns.boxplot(x="1991",y="1993",data=df)
plt.show()

# %%
sns.violinplot(df["2001"])
plt.show()

# %%
# finding out the counts for 1996
df["1996"].value_counts()
# Out:
# 1996
# 6.60     3
# 6.16     3
# 7.30     3
# 2.49     2
# 22.77    2
#         ..
# 8.28     1
# 11.84    1
# 7.42     1
# 2.83     1
# 6.25     1
# Name: count, Length: 217, dtype: int64

# %%
df = df.dropna(subset="1991")  # Removes rows where conversion failed
